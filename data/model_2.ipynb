# %%
from sklearn import tree
import pandas as pd
import os

# %%
df = pd.read_csv("main_data_feb1.csv")
df.head(10000)
# Out:
#         county  county_tier  poverty_county  median_inc_county    code  \
# 0     Alamance            2            18.3              50480   10384
# 1     Alamance            2            18.3              50480   10320
# 2     Alamance            2            18.3              50480   10347
# 3     Alamance            2            18.3              50480   10353
# 4     Alamance            2            18.3              50480   10324
# ...        ...          ...             ...                ...     ...
# 2479    Yancey            2            23.3              44756  995312
# 2480    Yancey            2            23.3              44756  995320
# 2481    Yancey            2            23.3              44756  995330
# 2482    Yancey            2            23.3              44756  995316
# 2483    Yancey            2            23.3              44756  995304
#
#                               name        city  \
# 0          South Mebane Elementary      Mebane
# 1             E M Yoder Elementary      Mebane
# 2     Audrey W. Garrett Elementary      Mebane
# 3                 Hawfields Middle      Mebane
# 4            Eastern Alamance High      Mebane
# ...                            ...         ...
# 2479         Burnsville Elementary  Burnsville
# 2480          Clearmont Elementary  Burnsville
# 2481        Mountain Heritage High  Burnsville
# 2482             Cane River Middle  Burnsville
# 2483         Bald Creek Elementary  Burnsville
#
#                                            full_address         long  \
# 0                    600 S 3rd Street, Mebane, NC 27302  -79.2752451
# 1                301 N Charles Street, Mebane, NC 27302   -79.275477
# 2          3224 Old Hillsborough Road, Mebane, NC 27302  -79.2968657
# 3                       1951 S NC 119, Mebane, NC 27302  -79.2972038
# 4                  4040 Mebane Rogers, Mebane, NC 27302   -79.302277
# ...                                                 ...          ...
# 2479   395 Burnsville School Road, Burnsville, NC 28714  -82.2580444
# 2480   1175 Clearmont School Road, Burnsville, NC 28714   -82.298263
# 2481     333 Mtn Heritage HS Road, Burnsville, NC 28714  -82.3332443
# 2482  1128 Cane River School Road, Burnsville, NC 28714  -82.3776488
# 2483   100 Bald Creek School Road, Burnsville, NC 28714   -82.423218
#
#              lat                     district percent_EDS SPgrade EOG_18_19  \
# 0     36.0888099  Alamance-Burlington Schools        41.2       B        69
# 1      36.100586  Alamance-Burlington Schools        40.8       B      64.1
# 2     36.0616231  Alamance-Burlington Schools        55.9       C      53.6
# 3     36.0614763  Alamance-Burlington Schools        53.5       B      68.5
# 4     36.1135494  Alamance-Burlington Schools        36.9       C      55.2
# ...          ...                          ...         ...     ...       ...
# 2479   35.917422        Yancey County Schools        61.5       C      55.4
# 2480   35.976992        Yancey County Schools          45       C      61.8
# 2481  35.9085435        Yancey County Schools        43.1       B      61.1
# 2482  35.9122092        Yancey County Schools        52.7       C      61.3
# 2483    35.91298        Yancey County Schools        58.6       A      85.3
#
#       EOG_quintile
# 0                2
# 1                2
# 2                3
# 3                2
# 4                3
# ...            ...
# 2479             3
# 2480             2
# 2481             2
# 2482             2
# 2483             1
#
# [2484 rows x 15 columns]

# %%
target = df["EOG_quintile"]
target_names = ["A", "B", "C","D","F"]

# %%
data = df.drop("EOG_quintile", axis=1)
feature_names = data.columns
data.head()
# Out:
#      county  county_tier  poverty_county  median_inc_county   code  \
# 0  Alamance            2            18.3              50480  10384
# 1  Alamance            2            18.3              50480  10320
# 2  Alamance            2            18.3              50480  10347
# 3  Alamance            2            18.3              50480  10353
# 4  Alamance            2            18.3              50480  10324
#
#                            name    city  \
# 0       South Mebane Elementary  Mebane
# 1          E M Yoder Elementary  Mebane
# 2  Audrey W. Garrett Elementary  Mebane
# 3              Hawfields Middle  Mebane
# 4         Eastern Alamance High  Mebane
#
#                                    full_address         long         lat  \
# 0            600 S 3rd Street, Mebane, NC 27302  -79.2752451  36.0888099
# 1        301 N Charles Street, Mebane, NC 27302   -79.275477   36.100586
# 2  3224 Old Hillsborough Road, Mebane, NC 27302  -79.2968657  36.0616231
# 3               1951 S NC 119, Mebane, NC 27302  -79.2972038  36.0614763
# 4          4040 Mebane Rogers, Mebane, NC 27302   -79.302277  36.1135494
#
#                       district percent_EDS SPgrade EOG_18_19
# 0  Alamance-Burlington Schools        41.2       B        69
# 1  Alamance-Burlington Schools        40.8       B      64.1
# 2  Alamance-Burlington Schools        55.9       C      53.6
# 3  Alamance-Burlington Schools        53.5       B      68.5
# 4  Alamance-Burlington Schools        36.9       C      55.2

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-919dfd680ef1> in <module>()
#       1 clf = tree.DecisionTreeClassifier()
# ----> 2 clf = clf.fit(X_train, y_train)
#       3 clf.score(X_test, y_test)
#
# C:\Users\Lunch\Anaconda3\envs\PythonData\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     875             sample_weight=sample_weight,
#     876             check_input=check_input,
# --> 877             X_idx_sorted=X_idx_sorted)
#     878         return self
#     879
#
# C:\Users\Lunch\Anaconda3\envs\PythonData\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     147
#     148         if check_input:
# --> 149             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     150             y = check_array(y, ensure_2d=False, dtype=None)
#     151             if issparse(X):
#
# C:\Users\Lunch\Anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     529                     array = array.astype(dtype, casting="unsafe", copy=False)
#     530                 else:
# --> 531                     array = np.asarray(array, order=order, dtype=dtype)
#     532             except ComplexWarning:
#     533                 raise ValueError("Complex data not supported\n"
#
# C:\Users\Lunch\Anaconda3\envs\PythonData\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: 'Edgecombe'
