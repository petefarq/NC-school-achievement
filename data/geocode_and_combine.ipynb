# %%
from googlemaps import Client as GoogleMaps
import pandas as pd

# %%
gmaps = GoogleMaps('API_Key_Here')

# %%
lat_longs = pd.read_csv("lat_longs.csv")
lat_longs.head()
# Out:
#      code                                  name            city  \
# 0   50303        Ashe County Early College High  West Jefferson
# 1   90376                  Bladen Early College          Dublin
# 2  120354              Mountain View Elementary       Morganton
# 3  160343  Marine Sci. & Tech. Early College HS   Morehead City
# 4  29A000          Davidson Charter Academy CFA       Lexington
#
#                                     full_address  long  lat  \
# 0     363 Campus Drive, West Jefferson, NC 28694   NaN  NaN
# 1             7418 NC Hwy 41 W, Dublin, NC 28332   NaN  NaN
# 2          805 Bouchelle St, Morganton, NC 28655   NaN  NaN
# 3  3505 Arendell Street, Morehead City, NC 28557   NaN  NaN
# 4          500 Biesecker Rd, Lexington, NC 27295   NaN  NaN
#
#                          district    county SPgrade EOG_18_19  ...  \
# 0             Ashe County Schools      Ashe       A     95.00  ...
# 1           Bladen County Schools    Bladen       C     54.50  ...
# 2            Burke County Schools     Burke       D     44.40  ...
# 3  Carteret County Public Schools  Carteret       A     88.10  ...
# 4                 Charter Schools  Davidson       D     42.30  ...
#
#    child_abuse_rate children_conc_pov  elevated_lead  juv_delinquent  \
# 0               5.2               0.0            1.1            12.3
# 1               2.4              16.2            0.9             7.1
# 2               2.7               0.0            0.9            23.2
# 3               7.6               2.6            0.6            13.3
# 4               3.3              12.3            1.0            17.6
#
#    No_HSdegree  parent_unemployed  county_poc  county_tier  poverty_county  \
# 0         12.5                5.5         7.1            2            23.3
# 1         19.1               15.8        44.7            1            41.8
# 2         17.0               12.5        17.6            2            19.9
# 3          6.2                7.4        12.3            2            15.5
# 4         15.1                8.7        19.3            2            20.0
#
#    median_inc_county
# 0              41864
# 1              36976
# 2              44946
# 3              55052
# 4              47758
#
# [5 rows x 22 columns]

# %%
lat_longs['long'] = ""
lat_longs['lat'] = ""

# %%
for x in range(len(lat_longs)):
    geocode_result = gmaps.geocode(lat_longs['full_address'][x])
    lat_longs['lat'][x] = geocode_result[0]['geometry']['location'] ['lat']
    lat_longs['long'][x] = geocode_result[0]['geometry']['location']['lng']
lat_longs.head()
# Out:
# C:\Users\petef\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\petef\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#      code                                  name            city  \
# 0   50303        Ashe County Early College High  West Jefferson
# 1   90376                  Bladen Early College          Dublin
# 2  120354              Mountain View Elementary       Morganton
# 3  160343  Marine Sci. & Tech. Early College HS   Morehead City
# 4  29A000          Davidson Charter Academy CFA       Lexington
#
#                                     full_address     long      lat  \
# 0     363 Campus Drive, West Jefferson, NC 28694 -81.4762  36.3942
# 1             7418 NC Hwy 41 W, Dublin, NC 28332 -78.7323   34.645
# 2          805 Bouchelle St, Morganton, NC 28655 -81.7015  35.7539
# 3  3505 Arendell Street, Morehead City, NC 28557 -76.7578  34.7241
# 4          500 Biesecker Rd, Lexington, NC 27295 -80.2691  35.8458
#
#                          district    county SPgrade EOG_18_19  ...  \
# 0             Ashe County Schools      Ashe       A     95.00  ...
# 1           Bladen County Schools    Bladen       C     54.50  ...
# 2            Burke County Schools     Burke       D     44.40  ...
# 3  Carteret County Public Schools  Carteret       A     88.10  ...
# 4                 Charter Schools  Davidson       D     42.30  ...
#
#    child_abuse_rate children_conc_pov  elevated_lead  juv_delinquent  \
# 0               5.2               0.0            1.1            12.3
# 1               2.4              16.2            0.9             7.1
# 2               2.7               0.0            0.9            23.2
# 3               7.6               2.6            0.6            13.3
# 4               3.3              12.3            1.0            17.6
#
#    No_HSdegree  parent_unemployed  county_poc  county_tier  poverty_county  \
# 0         12.5                5.5         7.1            2            23.3
# 1         19.1               15.8        44.7            1            41.8
# 2         17.0               12.5        17.6            2            19.9
# 3          6.2                7.4        12.3            2            15.5
# 4         15.1                8.7        19.3            2            20.0
#
#    median_inc_county
# 0              41864
# 1              36976
# 2              44946
# 3              55052
# 4              47758
#
# [5 rows x 22 columns]

# %%
lat_longs.to_csv('with_lat_long.csv')
